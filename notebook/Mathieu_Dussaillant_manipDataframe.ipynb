# %% [markdown]
# # Manipulation Dataframe

# %%
import pandas as pd

# préciser le chemin du fichier à lire
cheminDuFichierCSV = "./../data/dictionary/1757_Buchanan-J.csv" 

# demander à pandas de lire le fichier et garder ce tableau accessible dans une variable
dfDicoBuch = pd.read_csv(cheminDuFichierCSV, delimiter=";", encoding="utf8")

# afficher à l'écran un échantillon du tableau
dfDicoBuch.sample(n=5)
# Out:
#        nbSyll         pron origin warning remarques POS  lineId  pageId
# 10034       3  pĕrsŭāʹſive    NaN     NaN       NaN  a.     9.0     161
# 13584       2      tăʹngle    NaN     NaN       NaN  n.    45.0     210
# 1259        2       bēʹtle    NaN     NaN       NaN  n.     4.0      37
# 15435       2        wăʹry    NaN     NaN       NaN  a.    33.0     236
# 3953        1         dŏck    NaN     NaN       NaN  n.    46.0      74

# %%
# préciser le chemin du fichier à lire
cheminDuFichierCSV = "./../data/dictionary/Buchanan_PronChar_counts.csv" 

# demander à pandas de lire le fichier et garder ce tableau accessible dans une variable
dfDicoPronChar = pd.read_csv(cheminDuFichierCSV, delimiter=";", encoding="utf8")

# afficher à l'écran un échantillon du tableau
dfDicoPronChar.sample(n=5)
# Out:
#    char   occ graph
# 5     u  1623     u
# 68    á     1     a
# 10    ſ  4329     s
# 53    (    28   NaN
# 19    h  2383     h

# %%
dfDicoPronChar = dfDicoPronChar.dropna()

# %%
def sampa2ipa(strSampa, dfMapping):
    ipaRes = ""
    
    #print(listValSampa)
    for valSampa in strSampa:
        dfRowFinded = dfMapping[dfMapping['char']==valSampa]

        if len(dfRowFinded==1):
            ipaRes+=str(dfRowFinded.iloc[0]['graph'])
        else:
            ipaRes+=''
    return ipaRes

# %%
dfDicoBuch['headword'] = dfDicoBuch.apply(lambda x: sampa2ipa(x['pron'], dfDicoPronChar),1)

# %%
dfDicoBuch
# Out:
#        nbSyll        pron origin warning remarques POS  lineId  pageId  \
# 0           3     aʹbăcus    NaN     NaN       NaN  n.     2.0      19
# 1           2      ăbăʹft    NaN     NaN       NaN  p.     3.0      19
# 2           3  ăbaiʹſănce     F.     NaN       NaN  n.     4.0      19
# 3           3    ābăʹndon     F.     NaN       NaN  v.     5.0      19
# 4           4  ābăʹndŏned    NaN     NaN       NaN  a.     6.0      19
# ...       ...         ...    ...     ...       ...  ..     ...     ...
# 15795       4  zōŏʹgrăphy     G.     NaN       NaN  n.    19.0     241
# 15796       4  zōŏʹphytès     G.     NaN       NaN  n.    20.0     241
# 15797       4  zōŏʹphŏric     G.     NaN       NaN  n.    21.0     241
# 15798       4  zōŏʹtŏmiſt     G.     NaN       NaN  n.    22.0     241
# 15799       3     zŏʹtĭcā     G.     NaN       NaN  n.    23.0     241
#
#         headword
# 0         abacus
# 1          abaft
# 2      abaisance
# 3        abandon
# 4      abandoned
# ...          ...
# 15795  zoography
# 15796  zoophytes
# 15797  zoophoric
# 15798  zootomist
# 15799     zotica
#
# [15800 rows x 9 columns]

# %%
dfDicoBuch.to_csv("./../data/dictionary/DFfin.csv", sep= ";", index=False)
